# %% [markdown]
# A valuation model for Tesla could be based on a discounted cash flow (DCF) analysis, which estimates the present value of future cash flows generated by the company. The model would need to consider several factors, including:
#
# - Revenue projections: The model would need to estimate Tesla's future revenue based on factors such as projected growth in electric vehicle sales, sales of other products and services, and any potential future revenue streams.
#
# - Cost of goods sold: The model would need to estimate the cost of goods sold, including the cost of materials and labor, as well as research and development expenses.
#
# - Operating expenses: The model would need to estimate other operating expenses such as selling, general, and administrative expenses.
#
# - Capital expenditures: The model would need to estimate the amount of money the company will need to spend on capital expenditures, such as building new factories and purchasing new equipment.
#
# - Tax rate: The model would need to take into account the company's tax rate.
#
# - Discount rate: The model would need to use a discount rate, which is the rate at which future cash flows are discounted to their present value.
#
# - Terminal value: The model would need to estimate the company's terminal value, which is the value of the company beyond the forecast period.
#
# Once all of these factors have been considered, the model would calculate the present value of the company's future cash flows and use that value to estimate the company's intrinsic value. Comparing this intrinsic value to the current stock price would give you an idea of whether the stock is overvalued or undervalued.

# %% [markdown]
# ## Technical analysis:
#
# - Analysts use historical price and volume data to identify patterns and trends that may indicate future price movements.
#     - ARIMA model: ARIMA stands for Autoregressive Integrated Moving Average. It is a statistical model that uses historical price and volume data to identify patterns and trends that may indicate future price movements.
#     - Facebook Prophet: Prophet is a forecasting tool developed by Facebook. It uses historical price and volume data to identify patterns and trends that may indicate future price movements.
#
# ## Fundamentals analysis:
#
# - Analysts examine the financial performance and position of a company, including factors such as revenue, earnings, and debt levels, to determine the intrinsic value of the stock.
# - Research and Development
#     - affect of roboTaxi on the company's revenue
#         - Total Taxi US Market Value
#             - UBER
#                 - $59.69B
#             - LYFT
#                 - $5.52B
#     - affect of humanoid robot on economy
#
# ## Consensus estimates:
#
# - Analysts may also consider the average price target of other analysts covering the stock.
#
# ## Valuation models:
#
# - Analysts may use various valuation models such as discounted cash flow (DCF) model, Price to Earnings (P/E) model and Price to Sales (P/S) model to estimate the fair value of a stock.
#
# A valuation model for Tesla could be based on a discounted cash flow (DCF) analysis, which estimates the present value of future cash flows generated by the company. The model would need to consider several factors, including:
#
# - Revenue projections: The model would need to estimate Tesla's future revenue based on factors such as projected growth in electric vehicle sales, sales of other products and services, and any potential future revenue streams.
#
# - Cost of goods sold: The model would need to estimate the cost of goods sold, including the cost of materials and labor, as well as research and development expenses.
#
# - Operating expenses: The model would need to estimate other operating expenses such as selling, general, and administrative expenses.
#
# - Capital expenditures: The model would need to estimate the amount of money the company will need to spend on capital expenditures, such as building new factories and purchasing new equipment.
#
# - Tax rate: The model would need to take into account the company's tax rate.
#
# - Discount rate: The model would need to use a discount rate, which is the rate at which future cash flows are discounted to their present value.
#
# - Terminal value: The model would need to estimate the company's terminal value, which is the value of the company beyond the forecast period.
#
# Once all of these factors have been considered, the model would calculate the present value of the company's future cash flows and use that value to estimate the company's intrinsic value. Comparing this intrinsic value to the current stock price would give you an idea of whether the stock is overvalued or undervalued.
#
# ## News and events:
#
# - Analysts also keep an eye on news and events that may affect the value of a stock. Such as company's earnings, management changes, mergers and acquisitions, and regulatory changes.

# %% [markdown]
# ## Revenue Projections
#
# 1. Electric Vehicles
#     - Model S: Luxury Sedan
#     - Model 3: Sedan
#     - Model X: Luxury SUV
#     - Model Y: Compact SUV
#     - Cybertruck: Pickup truck
# 2. Commercial Vehicles
#     - Tesla Semi: Electric Semi-Truck
# 3. Solar Products
#     - Solar Panels
#     - Solar Roof Tiles
#     - Solar Inverter
#     - Software
# 4. Energy Storage
#     - Powerwall (Home)
#     - Megapack (Commercial)
#     - Powerpack (Utility)
#     - Grid Services
# 4. Supercharger Network
#     - Supercharger Stations
# 5. Tesla app
# 6. Autopilot / Full Self Driving (FSD)
#     - Taxi Service
# 7. Insurance
#     - Safety Score
#     - Score based Premiums
# 8. Other
#     - Optimus robot
#     - Dojo

# %% [markdown]
# ----

# %% [markdown]
# ### USA Sales
#
# - Prediction for 2023

# %% [markdown]
# | Year      |   Jan |   Feb |   Mar |   Apr |   May |   Jun |   Jul |   Aug |   Sep |   Oct |   Nov |   Dec |
# |:----------|------:|------:|------:|------:|------:|------:|------:|------:|------:|------:|------:|------:|
# | 2015      |     0 |  2000 |  1200 |  1700 |  1700 |  1700 |  1700 |  1700 |  1700 |  1730 |  1712 |  1900 |
# | 2016      |  2075 |  2150 |  2250 |  2250 |  2250 |  2250 |  2250 |  2250 |  2250 |  2250 |  2250 |  2250 |
# | 2017      |  2800 |  3000 |  3000 |  4400 |  4400 |  4400 |  4400 |  4400 |  4517 |  4545 |  4745 |  5460 |
# | 2018      |  6875 |  7485 |  8820 |  6150 | 11250 | 11062 | 16675 | 21700 | 29975 | 20325 | 24600 | 32600 |
# | 2019      |  8325 |  7650 | 14625 | 11925 | 16350 | 25025 | 15650 | 16025 | 23025 | 18612 | 19301 | 18612 |
# | 2020      | 22350 | 20450 | 10000 |  6624 | 14720 | 15456 | 48846 | 43418 | 47036 | 21591 | 17736 | 24675 |
# | 2021      | 21120 | 21120 | 23760 | 24751 | 23799 | 24751 | 28350 | 27301 | 28350 | 26232 | 26232 | 26232 |
# | 2022      | 37594 | 36202 | 89575 | 40568 | 39066 | 39066 | 37518 | 38962 | 37518 | 46667 | 44800 | 48533 |
# | Pred_2023 | 44709 | 45260 | 45181 | 45192 | 45190 | 45191 | 45191 | 45191 | 45191 | 45191 | 45191 | 45191 |

# %% [markdown]
# | Year      |  Total Sold |    Running Total |
# |:----------|-------:|-----------------:|
# | 2015      |  18742 |  18742           |
# | 2016      |  26725 |  45467           |
# | 2017      |  50067 |  95534           |
# | 2018      | 197517 | 293051           |
# | 2019      | 195125 | 488176           |
# | 2020      | 292902 | 781078           |
# | 2021      | 301998 |      1.08308e+06 |
# | 2022      | 536069 |      1.61914e+06 |
# | Pred_2023 | 541869 |      2.16101e+06 |

# %% [markdown]
# ![PRED_TeslaCumLogSales](output_images\PREDICT\PRED_TeslaCumLogSales.jpg)

# %% [markdown]
# ![PRED_TeslaCumSales](output_images\PREDICT\PRED_TeslaCumSales.jpg)

# %% [markdown]
# |   Year |   YOY Change (%) |   US Market Share (%) |   Market Share Change (%) |
# |---:|:-----------------:|:---------------------:|:-------------------------:|
# |   2015 |           nan    |                  0.11 |                    nan    |
# |   2016 |            42.59 |                  0.15 |                     36.36 |
# |   2017 |            87.34 |                  0.29 |                     93.33 |
# |   2018 |           294.51 |                  1.14 |                    293.1  |
# |   2019 |            -1.21 |                  1.15 |                      0.88 |
# |   2020 |            50.11 |                  1.99 |                     73.04 |
# |   2021 |             3.11 |                  2.02 |                      1.51 |
# |   2022 |            77.51 |                  3.92 |                     94.06 |

# %% [markdown]
# -----

# %% [markdown]
# ### Operational Summary

# %% [markdown]
# | Operational Summary                          |   2018 |   2019 |   2020 |   2021 |             2022 |   YOY % |
# |:---------------------------------------------|-------:|-------:|-------:|-------:|-----------------:|--------:|
# | Model S/X production                         | 101553 |  62931 |  54805 |  24390 |  71177           | 191.829 |
# | Model 3/Y production                         | 152977 | 302301 | 454932 | 906032 |      1.29843e+06 |  43.31  |
# | Total production                             | 254530 | 365232 | 509737 | 930422 |      1.36961e+06 |  47.203 |
# | Model S/X deliveries                         |  99451 |  66771 |  57085 |  24980 |  66705           | 167.034 |
# | Model 3/Y deliveries                         | 146055 | 300885 | 442562 | 911242 |      1.24715e+06 |  36.862 |
# | Total deliveries                             | 245506 | 367656 | 499647 | 936222 |      1.31385e+06 |  40.335 |
# | End of quarter operating lease vehicle count |  37134 |  49901 |  72089 | 120342 | 140667           |  16.889 |
# | Global vehicle inventory (days of supply)    |     22 |     13 |     15 |      6 |     16           | 166.667 |
# | Solar Deployment (MW)                        |    326 |    173 |    205 |    345 |    348           |   0.87  |
# | Storage Deployment (MWh)                     |   1041 |   1651 |   3022 |   3992 |   6541           |  63.853 |
# | Store and Service Locations                  |    378 |    433 |    523 |    644 |    764           |  18.634 |
# | Mobile Service Fleet                         |    411 |    758 |    894 |   1281 |   1584           |  23.653 |
# | Supercharger Stations                        |   1421 |   1821 |   2564 |   3476 |   4678           |  34.58  |
# | Supercharger Connectors                      |  12002 |  16104 |  23277 |  31498 |  42419           |  34.672 |

# %% [markdown]
# ![PRED_TeslaCumSales](output_images\HISTORICAL\TeslaProductionAndDeliveries.jpg)

# %% [markdown]
# ### Price of production

# %% [markdown]
# ### Global Sales

# %% [markdown]
# ### Stock Price
#
# #### Tesla Stock Price
#
# | ds                  |      y |    yhat |   yhat_lower |   yhat_upper |
# |:--------------------|-------:|--------:|-------------:|-------------:|
# | 2023-01-06 | 113.06 | 234.747 |      178.49  |      290.966 |
# | 2023-01-09 | 119.77 | 237.29  |      180.034 |      295.628 |
# | 2023-01-10 | 118.85 | 236.362 |      178.858 |      293.698 |
# | 2023-01-11 | 123.22 | 236.595 |      179.046 |      294.869 |
# | 2023-01-12 | 123.56 | 236.313 |      179.54  |      293.117 |
# | 2023-01-13 | 122.4  | 235.8   |      178.765 |      293.03  |
# | 2023-01-17 | 131.49 | 236.113 |      178.278 |      293.091 |
# | 2023-01-18 | 128.78 | 236.117 |      178.307 |      292.328 |
# | 2023-01-19 | 127.17 | 235.662 |      177.378 |      293.825 |
# | 2023-01-20 | 133.42 | 235.039 |      178.097 |      294.769 |
# | 2023-01-23 | 143.75 | 236.623 |      181.464 |      294.416 |
# | 2023-01-24 | 143.89 | 235.57  |      178.007 |      292.586 |
# | 2023-01-25 | 144.43 | 235.783 |      178.445 |      293.278 |
# | 2023-01-26 | 160.27 | 235.586 |      179.622 |      292.245 |
# | 2023-01-27 | 177.9  | 235.262 |      177.106 |      292.824 |
# | 2023-01-28 | nan    | 236.167 |      179.997 |      292.912 |
# | 2023-01-29 | nan    | 236.449 |      178.865 |      294.669 |
# | 2023-01-30 | nan    | 237.869 |      181.074 |      297.06  |
# | 2023-01-31 | nan    | 237.155 |      179.591 |      293.137 |
# | 2023-02-01 | nan    | 237.685 |      180.906 |      295.72  |
# | 2023-02-02 | nan    | 237.767 |      180.456 |      295.315 |
# | 2023-02-03 | nan    | 237.672 |      180.055 |      294.888 |
# | 2023-02-04 | nan    | 238.745 |      180.644 |      295.433 |
# | 2023-02-05 | nan    | 239.124 |      181.95  |      294.337 |
# | 2023-02-06 | nan    | 240.559 |      182.072 |      297.246 |
#
# ![additive_plot_forecast](output_images\PROPHET\TSLA_additive_plot_forecast.jpg)

# %% [markdown]
# ### Electric Vehicles

# %% [markdown]
# ### Commercial Vehicles

# %% [markdown]
# ### Solar Products
#
# Solar panels: Tesla produces high-efficiency solar panels that can be installed on a homeowner's roof. These panels convert sunlight into electricity that can be used to power a home or sent back to the grid for credits on the homeowner's utility bill.
#
# Solar Roof Tiles: Tesla solar roof tiles are designed to look like traditional roofing materials while also generating electricity from the sun.
#
# Powerwall: Tesla's Powerwall is a home battery system that stores energy generated by solar panels or from the grid during low-rate periods, allowing homeowners to use that energy at night or during power outages.
#
# Solar Inverter: Tesla's Solar Inverter is a device that converts the direct current (DC) electricity generated by solar panels into alternating current (AC) electricity that can be used in the home.
#
# Solar Software: Tesla's solar software allows customers to monitor their solar panel system and energy usage in real-time, with the ability to track energy production, consumption, and savings.
#
# All of these products work together to provide a comprehensive solar energy solution for homeowners, allowing them to generate, store and use their own clean energy.

# %% [markdown]
# ### Energy Storage
#
# Powerpack: Tesla's Powerpack is a commercial and utility-scale energy storage system that can store large amounts of energy generated by solar or wind power, and then release it to the grid as needed.
#
# Powerwall: Tesla's Powerwall is a home battery system that stores energy generated by solar panels or from the grid during low-rate periods, allowing homeowners to use that energy at night or during power outages.
#
# Megapack: Tesla's Megapack is a large-scale energy storage system designed for utility companies and renewable energy projects.
#
# Grid Services: Tesla's energy storage systems can provide grid services such as frequency regulation, load shifting and peak shaving to the electric grid.
#
# All of these products are designed to store energy when it's plentiful and release it when it's needed, helping to balance the grid and increase the use of renewable energy. They also provide backup power during power outages, which is important for businesses and critical infrastructure.

# %% [markdown]
# ### Supercharger Network
#
# Tesla's Supercharger network is a network of fast-charging stations for Tesla electric vehicles. The Superchargers can charge a Tesla vehicle's battery to 80% in as little as 30 minutes.
#
# The Supercharger stations are strategically located along major highways and in urban areas, making it convenient for Tesla owners to charge their vehicles while on long trips. The Superchargers are exclusively for Tesla vehicles, and can be located using the on-board navigation system or the Tesla app.
#
# The Supercharger network is constantly expanding, with new locations being added regularly. Tesla owners can use the Superchargers for free for a certain amount of time per year, after which they are charged a small fee.
#
# The Supercharger network is a key component of Tesla's strategy to increase the adoption of electric vehicles and to make long-distance travel in an electric vehicle more convenient. With the increasing number of Tesla vehicles on the road, the Supercharger network is expected to continue growing in the future.

# %% [markdown]
# ### Tesla App
#
# The Tesla app is a mobile application that allows Tesla vehicle owners to control certain features of their vehicles, track charging status, and locate Superchargers. The app is available for both iOS and Android devices.
#
# Some of the features that can be controlled using the Tesla app include:
#
# Remotely controlling the charging status of the vehicle
# Preconditioning the vehicle's cabin
# Locating and navigating to the vehicle
# Locking and unlocking the vehicle
# Starting or stopping the vehicle
# The app also provides information about the vehicle's battery level, estimated range, and odometer reading. It also allows you to check the status of your Supercharger sessions, and start or stop them. The app can also be used to track the energy usage of the Tesla Powerwall and monitor the Solar Panels Production.
#
# Additionally, the app allows you to view the live stream of the vehicle's camera, change the vehicle's settings, and access the Sentry Mode (if enabled) and the Dashcam.
#
# Overall, the Tesla app is a convenient tool that allows Tesla vehicle owners to manage and monitor their vehicles remotely, making it easier to stay connected to their vehicle and optimize its use.

# %% [markdown]
# ### Autopilot / Full Self Driving (FSD)

# %% [markdown]
# ### Insurance

# %% [markdown]
# ## Cost of Goods Sold
#
# Cost of goods sold
#    - Materials
#    - Labor
#    - Research and Development
